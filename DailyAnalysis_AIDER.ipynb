# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('IndexedDataset.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
from sklearn import linear_model
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline 
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 14, 7

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

# %%
df.head(5)
# Out:
#                      Sales
# Date
# 2018-08-31 21:22:35  21.34
# 2018-08-31 21:27:53  18.85
# 2018-08-31 21:31:06   3.54
# 2018-08-31 21:33:47   5.57
# 2018-08-31 22:13:22  18.33

# %%
##Daily Overview

# %%
df.loc['2018-10-08'].describe()
# Out:
#             Sales
# count  111.000000
# mean    21.272342
# std     20.556125
# min    -21.440000
# 25%      9.180000
# 50%     16.210000
# 75%     26.730000
# max    146.800000

# %%
df.loc[df['Sales'] < 0,'Sales'] = 0

## Replace negative numbers with 0.

# %%
df.describe()
# Out:
#               Sales
# count  52815.000000
# mean      20.919007
# std       19.826868
# min        0.000000
# 25%        9.060000
# 50%       15.440000
# 75%       26.630000
# max     1115.230000

# %%
df.to_csv(r'../SciPY/EDA_dataset.csv')

# %%
df.plot()

# %%
df.head(10)
# Out:
#                      Sales
# Date
# 2018-08-31 21:22:35  21.34
# 2018-08-31 21:27:53  18.85
# 2018-08-31 21:31:06   3.54
# 2018-08-31 21:33:47   5.57
# 2018-08-31 22:13:22  18.33
# 2018-08-31 22:19:17  18.98
# 2018-08-31 22:27:21  28.79
# 2018-08-31 22:29:21  19.07
# 2018-08-31 22:31:14   7.09
# 2018-08-31 22:41:13   9.53

# %%
df.tail(10)
# Out:
#                      Sales
# Date
# 2019-09-20 02:54:19  23.53
# 2019-09-20 02:58:46   7.96
# 2019-09-20 03:01:01   8.57
# 2019-09-20 03:04:12  70.12
# 2019-09-20 03:08:41  15.15
# 2019-09-20 03:12:11  14.00
# 2019-09-20 03:12:46  20.46
# 2019-09-20 03:16:20   6.88
# 2019-09-20 03:17:59  11.56
# 2019-09-20 03:19:47  12.26

# %%
df.describe()
# Out:
#               Sales
# count  52815.000000
# mean      20.919007
# std       19.826868
# min        0.000000
# 25%        9.060000
# 50%       15.440000
# 75%       26.630000
# max     1115.230000

# %%
sorted_sales = df.sort_values(by=['Sales'], ascending=False)

# %%
sorted_sales.head(10)
# Out:
#                        Sales
# Date
# 2019-04-17 05:29:19  1115.23
# 2018-12-08 06:01:43   717.93
# 2019-01-25 21:25:25   506.29
# 2019-04-19 23:08:03   504.46
# 2019-02-08 01:29:05   470.29
# 2019-01-17 23:11:20   427.97
# 2019-06-30 00:31:55   416.12
# 2019-03-08 22:43:48   407.96
# 2018-12-12 23:04:29   374.64
# 2019-02-05 07:04:56   357.64

# %%
sorted_sales_min = df.sort_values(by=['Sales'], ascending=True)

# %%
print(sorted_sales_min['Sales'].head(12))
# Out:
# Date
# 2019-01-16 22:03:51    0.0
# 2018-09-25 02:35:51    0.0
# 2018-11-03 00:37:23    0.0
# 2019-05-13 21:23:59    0.0
# 2018-10-29 01:29:19    0.0
# 2019-01-27 22:17:37    0.0
# 2019-04-11 23:37:28    0.0
# 2018-09-07 01:39:54    0.0
# 2019-07-04 01:04:20    0.0
# 2018-09-19 00:41:37    0.0
# 2018-10-06 21:06:17    0.0
# 2018-09-04 01:00:14    0.0
# Name: Sales, dtype: float64

# %%
df.loc['2018-08'].describe()
# Out:
#            Sales
# count  27.000000
# mean   15.996667
# std    11.449998
# min     3.540000
# 25%     7.800000
# 50%    13.200000
# 75%    19.025000
# max    48.640000

# %%
df.loc['2018-08'].plot()

# %%
df.loc['2018-08':'2018-12'].plot()

# %%
df.loc['2018-12-08':'2018-12-09'].sort_values(by=['Sales'], ascending=False)
# Out:
#                       Sales
# Date
# 2018-12-08 06:01:43  717.93
# 2018-12-09 01:23:30  117.62
# 2018-12-08 04:40:34   96.56
# 2018-12-08 04:21:11   88.32
# 2018-12-08 23:40:35   74.57
# ...                     ...
# 2018-12-09 00:33:58    3.44
# 2018-12-08 01:48:53    3.36
# 2018-12-08 00:46:51    2.88
# 2018-12-09 00:55:14    2.86
# 2018-12-08 09:05:57    2.83
#
# [300 rows x 1 columns]

# %%
df.loc['2018-12-03':'2018-12-09'].plot()

# %%
df.loc['2018-12-10':'2018-12-16'].plot()

# %%
df.loc['2018-08-31':'2018-12-31'].sort_values(by=['Sales'], ascending=False).head(20)
# Out:
#                       Sales
# Date
# 2018-12-08 06:01:43  717.93
# 2018-12-12 23:04:29  374.64
# 2018-12-30 23:21:02  321.21
# 2018-11-09 22:22:44  306.38
# 2018-12-16 21:49:49  296.06
# 2018-09-28 21:44:53  237.35
# 2018-12-16 23:45:45  227.20
# 2018-10-16 01:02:37  224.40
# 2018-12-31 00:54:38  209.76
# 2018-12-17 22:16:06  205.00
# 2018-12-30 01:30:46  202.78
# 2018-09-07 23:00:41  201.03
# 2018-12-27 22:15:04  196.04
# 2018-12-31 23:30:54  190.54
# 2018-12-20 22:14:53  179.70
# 2018-11-17 22:43:23  174.22
# 2018-12-23 00:08:46  169.80
# 2018-12-29 23:31:06  165.60
# 2018-12-26 20:52:38  164.71
# 2018-10-02 21:22:13  163.31

# %%
df.loc['2018-08-01':'2018-08-31'].describe()
# Out:
#            Sales
# count  27.000000
# mean   15.996667
# std    11.449998
# min     3.540000
# 25%     7.800000
# 50%    13.200000
# 75%    19.025000
# max    48.640000

# %%
df.loc['2018-08-31':'2018-12-31'].describe()
# Out:
#               Sales
# count  16716.000000
# mean      20.646630
# std       19.427966
# min        0.000000
# 25%        8.850000
# 50%       15.210000
# 75%       26.202500
# max      717.930000

# %%
df.loc['2018-08-31':'2018-12-31'].mean()
# Out:
# Sales    20.64663
# dtype: float64

# %%
df.loc['2018-08-31':'2018-12-31'].std()
# Out:
# Sales    19.427966
# dtype: float64

# %%
df.loc['2018-08-31':'2018-12-31'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16716 entries, 2018-08-31 21:22:35 to 2018-12-31 23:58:44
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   16716 non-null  float64
# dtypes: float64(1)
# memory usage: 261.2 KB

# %%
df.loc['2018-08-31':'2018-12-31'].to_csv(r'../SciPY/EDA_Q1_dataset.csv')

# %%
df.loc['2018-12-17':'2018-12-23'].plot()

# %%
df.loc['2018-09-01':'2018-09-30'].plot()

# %%
df.loc['2018-09-01':'2018-09-30'].describe()
# Out:
#             Sales
# count  2897.00000
# mean     19.81710
# std      16.80899
# min       0.00000
# 25%       8.88000
# 50%      15.32000
# 75%      25.39000
# max     237.35000

# %%
df.loc['2018-10-01':'2018-10-31'].plot()

# %%
df.loc['2018-10-01':'2018-10-31'].describe()
# Out:
#              Sales
# count  4047.000000
# mean     20.479696
# std      17.970960
# min       0.000000
# 25%       8.750000
# 50%      14.870000
# 75%      26.200000
# max     224.400000

# %%
df.loc['2018-09-01':'2018-10-31'].to_csv(r'../SciPY/EDA_Q2_dataset.csv')

# %%
df.loc['2018-11-01':'2018-11-30'].plot()

# %%
df.loc['2018-11-01':'2018-11-30'].to_csv(r'../SciPY/EDA_Q3_dataset.csv')

# %%
df.loc['2018-11-01':'2018-11-30'].describe()
# Out:
#              Sales
# count  4578.000000
# mean     19.512997
# std      16.737609
# min       0.000000
# 25%       8.722500
# 50%      14.860000
# 75%      24.915000
# max     306.380000

# %%
df.loc['2018-12-01':'2018-12-31'].plot()

# %%
df.loc['2018-12-01':'2018-12-31'].describe()
# Out:
#              Sales
# count  5167.000000
# mean     22.271181
# std      23.595812
# min       0.000000
# 25%       9.060000
# 50%      15.820000
# 75%      27.770000
# max     717.930000

# %%
df.loc['2018-12-24':'2018-12-31'].plot()

# %%
df.loc['2018-12-28':'2018-12-29'].plot()

# %%
df.loc['2019-01-01':'2019-01-31'].plot()

# %%
df.loc['2019-01-01':'2019-01-31'].describe()
# Out:
#              Sales
# count  6801.000000
# mean     21.842464
# std      21.031426
# min       0.000000
# 25%       9.150000
# 50%      15.900000
# 75%      27.530000
# max     506.290000

# %%
df.loc['2019-02-01':'2019-02-28'].plot()

# %%
df.loc['2019-02-01':'2019-02-28'].describe()
# Out:
#              Sales
# count  6063.000000
# mean     20.792085
# std      19.465386
# min       0.900000
# 25%       9.180000
# 50%      15.500000
# 75%      26.360000
# max     470.290000

# %%
df.loc['2019-03-01':'2019-03-31'].plot()

# %%
df.loc['2019-03-01':'2019-03-31'].describe()
# Out:
#              Sales
# count  5478.000000
# mean     19.929527
# std      17.772699
# min       0.000000
# 25%       8.830000
# 50%      15.090000
# 75%      25.587500
# max     407.960000

# %%
df.loc['2019-04-01':'2019-04-30'].plot()

# %%
df.loc['2019-04-01':'2019-04-30'].describe()
# Out:
#              Sales
# count  4762.000000
# mean     22.351690
# std      26.007011
# min       0.000000
# 25%       9.312500
# 50%      16.080000
# 75%      28.575000
# max    1115.230000

# %%
df.loc['2019-05-01':'2019-05-31'].plot()

# %%
df.loc['2019-05-01':'2019-05-31'].describe()
# Out:
#              Sales
# count  3243.000000
# mean     20.453605
# std      17.186625
# min       0.000000
# 25%       9.230000
# 50%      15.330000
# 75%      25.475000
# max     151.810000

# %%
df.loc['2019-06-01':'2019-06-30'].plot()

# %%
df.loc['2019-06-01':'2019-06-30'].describe()
# Out:
#              Sales
# count  2348.000000
# mean     20.529889
# std      20.351369
# min       0.000000
# 25%       9.017500
# 50%      15.075000
# 75%      25.692500
# max     416.120000

# %%
df.loc['2019-07-01':'2019-07-31'].plot()

# %%
df.loc['2019-07-01':'2019-07-31'].describe()
# Out:
#              Sales
# count  2819.000000
# mean     20.695204
# std      18.470071
# min       0.000000
# 25%       8.945000
# 50%      15.220000
# 75%      26.280000
# max     246.400000

# %%
df.loc['2019-08-01':'2019-08-31'].plot()

# %%
df.loc['2019-08-01':'2019-08-31'].describe()
# Out:
#              Sales
# count  2776.000000
# mean     21.081146
# std      16.457233
# min       2.060000
# 25%       9.440000
# 50%      16.225000
# 75%      27.680000
# max     163.550000

# %%
df.loc['2019-09-01':'2019-09-20'].plot()

# %%
df.loc['2019-09-20'].plot()

# %%
df.loc['2019-09-01':'2019-09-20'].describe()
# Out:
#              Sales
# count  1809.000000
# mean     21.053809
# std      17.143217
# min       0.000000
# 25%       9.490000
# 50%      15.750000
# 75%      27.490000
# max     166.920000
